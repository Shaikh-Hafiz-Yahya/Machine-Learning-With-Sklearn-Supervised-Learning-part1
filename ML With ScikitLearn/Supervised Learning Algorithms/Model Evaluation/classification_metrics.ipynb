# %%
from sklearn.metrics import precision_score , recall_score , f1_score , accuracy_score

# %%
# pehly sy moujood input data k through ye output
y_actual = [1 , 0 , 1 , 1 , 0 , 1 , 0]

# unknown input data k through ye output/prediction 
y_predicted = [1 , 0 , 1, 0 , 0 , 1 , 1]

# %%
# evaluation
print('Accuracy:',accuracy_score(y_actual , y_predicted))
print('Precision:',precision_score(y_actual , y_predicted))
print('Recall:',recall_score(y_actual , y_predicted))
print('F1:',f1_score(y_actual , y_predicted))
# Out:
# Accuracy: 0.7142857142857143
# Precision: 0.75
# Recall: 0.75
# F1: 0.75

# %% [markdown]
# # Confusion Metrics/Performance Metrics

# %%
from sklearn.metrics import confusion_matrix

# %%
y_actual = [1 , 0 , 1 , 1 , 0 , 1 , 0 , 1]
y_predicted = [1 , 0 , 1 , 0 , 0 , 1 , 1 , 1]

# %%
cm = confusion_matrix(y_actual , y_predicted)
cm
# Out:
# array([[2, 1],
#        [1, 4]])
